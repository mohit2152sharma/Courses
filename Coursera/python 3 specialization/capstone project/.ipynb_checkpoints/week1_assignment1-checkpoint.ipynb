# %% [markdown]
# # Assignment 1: Building a Better Contact Sheet
# In the lectures for this week you were shown how to make a contact sheet for digital photographers, and how you can take one image and create nine different variants based on the brightness of that image. In this assignment you are going to change the colors of the image, creating variations based on a single photo. There are many complex ways to change a photograph using variations, such as changing a black and white image to either "cool" variants, which have light purple and blues in them, or "warm" variants, which have touches of yellow and may look sepia toned. In this assignment, you'll be just changing the image one color channel at a time
#
# Your assignment is to learn how to take the stub code provided in the lecture (cleaned up below), and generate the following output image:
#
# ![](./readonly/assignment1.png "")
#
# From the image you can see there are two parameters which are being varied for each sub-image. First, the rows are changed by color channel, where the top is the red channel, the middle is the green channel, and the bottom is the blue channel. Wait, why don't the colors look more red, green, and blue, in that order? Because the change you to be making is the ratio, or intensity, or that channel, in relationship to the other channels. We're going to use three different intensities, 0.1 (reduce the channel a lot), 0.5 (reduce the channel in half), and 0.9 (reduce the channel only a little bit).
#
# For instance, a pixel represented as (200, 100, 50) is a sort of burnt orange color. So the top row of changes would create three alternative pixels, varying the first channel (red). one at (20, 100, 50), one at (100, 100, 50), and one at (180, 100, 50). The next row would vary the second channel (blue), and would create pixels of color values (200, 10, 50), (200, 50, 50) and (200, 90, 50).
#
# Note: A font is included for your usage if you would like! It's located in the file `readonly/fanwood-webfont.ttf`
#
# Need some hints? Use them sparingly, see how much you can get done on your own first! The sample code given in the class has been cleaned up below, you might want to start from that.

# %%
import PIL
from PIL import Image
from PIL import ImageEnhance
from PIL import ImageDraw
import numpy as np

# read image and convert to RGB
image=Image.open("readonly/msi_recruitment.gif")
image=image.convert('RGB')

# build a list of 9 images which have different brightnesses
enhancer=ImageEnhance.Brightness(image)
images=[]

for i in range(1, 10):       
    images.append(enhancer.enhance(i/10))
    
# create a contact sheet from different brightnesses
first_image=images[0]
contact_sheet=PIL.Image.new(first_image.mode, (first_image.width*3,first_image.height*3))
x=0
y=0

for img in images:
    # Lets paste the current image into the contact sheet
    contact_sheet.paste(img, (x, y) )
    # Now we update our X position. If it is going to be the width of the image, then we set it to 0
    # and update Y as well to point to the next "line" of the contact sheet.
    if x+first_image.width == contact_sheet.width:
        x=0
        y=y+first_image.height
    else:
        x=x+first_image.width

# resize and display the contact sheet
contact_sheet = contact_sheet.resize((int(contact_sheet.width/2),int(contact_sheet.height/2) ))
display(contact_sheet)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-476150f334f7> in <module>()
#       6
#       7 # read image and convert to RGB
# ----> 8 image=Image.open("readonly/msi_recruitment.gif")
#       9 image=image.convert('RGB')
#      10
#
# C:\Users\kswp234\AppData\Local\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2408
#    2409     if filename:
# -> 2410         fp = builtins.open(filename, "rb")
#    2411         exclusive_fp = True
#    2412
#
# FileNotFoundError: [Errno 2] No such file or directory: 'readonly/msi_recruitment.gif'

# %%
pixelMapOrig = image.load()
new_image = Image.new(image.mode, (image.width, image.height), "black")
pixelMap2Change = new_image.load()
for i in range(image.size[0]):
    for j in range(image.size[1]):
        r, g, b = pixelMapOrig[i,j]
        pixelMap2Change[i, j] = (int(r*0.1), g, b)
        
new_image.show()
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x450 at 0x7F2F452BA2B0>

# %%
from PIL import Image, ImageDraw, ImageFont

images = []

pixelMapOrig = image.load()
intensities = [0.1, 0.5, 0.9]
channels = ['0', '1', '2']
fnt = ImageFont.truetype("readonly/fanwood-webfont.ttf", 75)

def text_func(image, string):
    base = image.convert("RGBA")
    txt = Image.new('RGBA', (base.width, base.height - 400), "black")
    d = ImageDraw.Draw(txt)
    d.text((0, 5), string, font=fnt, fill=(255,255,255,255))
    box = (0, base.height - txt.height)
    base.paste(txt, box)
    return base
    
def change_intensity(param):
    for intensity in intensities:
        new_image = Image.new(image.mode, image.size, "black") #creating a black image
        pixelMap2Change = new_image.load() #for changing the pixels of black image

        for i in range(new_image.size[0]):
            for j in range(new_image.size[1]):
                r, g, b = pixelMapOrig[i, j]
                if param == 'r':
                    pixelMap2Change[i, j] = (int(r*intensity), g, b)
                    string = "channel 0 intensity {}".format(intensity)
                    text_func(image=new_image, string=string)    
                elif param == 'g':
                    pixelMap2Change[i, j] = (r, int(g*intensity), b)
                    string = "channel 1 intensity {}".format(intensity)
                    text_func(image=new_image, string=string)
                else:
                    pixelMap2Change[i, j] = (r, g, int(b*intensity))
                    string = "channel 2 intensity {}".format(intensity)
                    text_func(image=new_image, string=string)
        
        images.append(base)
    
for param in ['r', 'g', 'b']:
    change_intensity(param=param)

first_image=images[0]
contact_sheet=PIL.Image.new(first_image.mode, (first_image.width*3,first_image.height*3))
x=0
y=0

for img in images:
    # Lets paste the current image into the contact sheet
    contact_sheet.paste(img, (x, y) )
    # Now we update our X position. If it is going to be the width of the image, then we set it to 0
    # and update Y as well to point to the next "line" of the contact sheet.
    if x+first_image.width == contact_sheet.width:
        x=0
        y=y+first_image.height
    else:
        x=x+first_image.width

# resize and display the contact sheet
contact_sheet = contact_sheet.resize((int(contact_sheet.width/2),int(contact_sheet.height/2) ))
display(contact_sheet)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-daa7d3a051a1> in <module>
#      41
#      42 for param in ['r', 'g', 'b']:
# ---> 43     change_intensity(param=param)
#      44
#      45 first_image=images[0]
#
# <ipython-input-3-daa7d3a051a1> in change_intensity(param)
#      28                     pixelMap2Change[i, j] = (int(r*intensity), g, b)
#      29                     string = "channel 0 intensity {}".format(intensity)
# ---> 30                     text_func(image=new_image, string=string)
#      31                 elif param == 'g':
#      32                     pixelMap2Change[i, j] = (r, int(g*intensity), b)
#
# <ipython-input-3-daa7d3a051a1> in text_func(image, string)
#      12     txt = Image.new('RGBA', (base.width, base.height - 400), "black")
#      13     d = ImageDraw.Draw(txt)
# ---> 14     d.text((0, 5), string, font=fnt, fill=(255,255,255,255))
#      15     box = (0, base.height - txt.height)
#      16     base.paste(txt, box)
#
# /opt/conda/lib/python3.7/site-packages/PIL/ImageDraw.py in text(self, xy, text, fill, font, anchor, *args, **kwargs)
#     273             try:
#     274                 mask, offset = font.getmask2(text, self.fontmode,
# --> 275                                              *args, **kwargs)
#     276                 xy = xy[0] + offset[0], xy[1] + offset[1]
#     277             except AttributeError:
#
# /opt/conda/lib/python3.7/site-packages/PIL/ImageFont.py in getmask2(self, text, mode, fill, direction, features, *args, **kwargs)
#     185         size, offset = self.font.getsize(text, direction, features)
#     186         im = fill("L", size, 0)
# --> 187         self.font.render(text, im.id, mode == "1", direction, features)
#     188         return im, offset
#     189
#
# KeyboardInterrupt:

# %%
from PIL import Image, ImageDraw, ImageFont
# get an image
base = image.convert('RGBA')

# make a blank image for the text, initialized to transparent text color
txt = Image.new('RGBA', (base.width, base.height - 400), "black")

# get a font
fnt = ImageFont.truetype("readonly/fanwood-webfont.ttf", 50)
# get a drawing context
d = ImageDraw.Draw(txt)

# draw text, half opacity
d.text((0, 5), "Hello World", font=fnt, fill=(255,255,255,255))
# draw text, full opacity
#d.text((10,image.size[1] -50), "World", font=fnt, fill=(255,255,255,255))

#out = Image.alpha_composite(base, txt)
box = (0, base.height - txt.height)
base.paste(txt, box)
#out.show()
display(base)
image.size

# %% [markdown]
# ## HINT 1
#
# Check out the `PIL.ImageDraw module` for helpful functions

# %% [markdown]
# ## HINT 2
#
# Did you find the `text()` function of `PIL.ImageDraw`?

# %% [markdown]
# ## HINT 3
#
# Have you seen the `PIL.ImageFont` module? Try loading the font with a size of 75 or so.

# %% [markdown]
# ## HINT 4
# These hints aren't really enough, we should probably generate some more.
